# %% [markdown]
# ## E-commerce.

# %% [markdown]
# #### Goals:
# * Exploratory analysis
# * Cohort segmentation
# * RFM-analysis segmentation

# %% [markdown]
# #### 💾 Data description:

# %% [markdown]
# `olist_customers_datase.csv` — table with unique user ids
# * `customer_id` — user id by orders
# * `customer_unique_id` — unique user ids
# * `customer_zip_code_prefix` —  postcode
# * `customer_city` —  user's city for delivery
# * `customer_state` —  user's state for delivery

# %% [markdown]
# `olist_orders_dataset.csv` —  table with orders
#
# * `order_id` —  unique order id (receipt number)
# * `customer_id` —  user id by orders
# * `order_status` —  order status
#     * created
#     * approved
#     * invoiced
#     * processing
#     * shipped
#     * delivered
#     * unavailable
#     * canceled
# * `order_purchase_timestamp` —  order created timestamp
# * `order_approved_at` —  payment approved timestamp
# * `order_delivered_carrier_date` —  transfer to carrier timestamp
# * `order_delivered_customer_date` —  delivered to customer timestamp
# * `order_estimated_delivery_date` —  estimated delivery timestamp

# %% [markdown]
# `olist_order_items_dataset.csv` —  items available to order
# * `order_id` —  unique order id (receipt number)
# * `order_item_id` —  item number within an order
# * `product_id` —  item id
# * `seller_id` — seller id
# * `shipping_limit_date` —  deadline for the seller to trasfer the order to the logistics partner
# * `price` —  price per item
# * `freight_value` —  item weight

# %% [markdown]
# NB: Not all the columns will be used in the analysis.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import calendar

import requests
from urllib.parse import urlencode

from datetime import timedelta
import matplotlib.pyplot as plt

# %%
# Getting links to download the datasets

base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'

public_keys = ['https://disk.yandex.ru/d/QXrVDUoQvFhIcg', 
               'https://disk.yandex.ru/d/0zWmh1bYP6REbw', 
               'https://disk.yandex.ru/d/xCsQ0FiC-Ue4Lg']

urls = []
for key in public_keys:
    final_url = base_url + urlencode(dict(public_key=key))
    response = requests.get(final_url)
    download_url = response.json()['href']
    urls.append(download_url)

download_url_customers = urls[0]
download_url_orders = urls[1]
download_url_order_items = urls[2]

# %%
# download_url_customers

# %%
customers = pd.read_csv(download_url_customers)

# %%
orders = pd.read_csv(download_url_orders)

# %%
order_items = pd.read_csv(download_url_order_items)

# %% [markdown]
# Sneak peek at the data and define what should be considered to be a purchase.

# %%
# Declare the function describing basic information about our dataframes

def df_describe(df, id_col=0):
    """
    Returns information about df shape, value types, duplicates and missing values.
    
    Parameters
    ----------
    df: DataFrame object.
    id_col: int, default 0.
    """
    print(f'Shape:{df.shape} \n')
    print(f'Value types:\n{df.dtypes} \n')
    print(f'Duplicated IDs:{df.iloc[:, id_col].duplicated().sum()} \n')
    print(f'Missing values:\n{df.isna().sum()}')

# %%
# Look at orders table

orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df_describe(orders)
# Out:
# Shape:(99441, 8)
#
# Value types:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object
#
# Duplicated IDs:0
#
# Missing values:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Summary:
# * Order statuses fields are object, while should be timestamp;
# * No duplicated order IDs;
# * Missing values in `order_approved_at`, `order_delivered_carrier_date` and `order_delivered_customer_date`, which is acceptable because some orders might not be delivered yet. It needs to be investigated though because the carrier might have a problem.

# %%
# Look at cusomers table

customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_describe(customers, id_col=1)
# Out:
# Shape:(99441, 5)
#
# Value types:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#
# Duplicated IDs:3345
#
# Missing values:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Summary:
# * All value types are correct;
# * No missing values;
# * Lots of duplicated unique customer IDs. Let's look closer.

# %%
customers[customers.customer_unique_id.duplicated()].sort_values('customer_unique_id') #doesn't give much info
# Out:
#                             customer_id                customer_unique_id  \
# 35608  24b0e2bd287e47d54d193e7bbb51103f  00172711b30d52eea8b313a7f2cced02
# 22066  f6efe5d5c7b85e12355f9d5c3db46da2  004288347e5e88a27ded2bb23747066c
# 87012  d95f60d70d9ea9a7fe37c53c931940bb  004b45ec5c64187465168251cd1c9c2f
# 61403  f530197ea86ced9488a03d055e118ebf  0058f300f57d7b93c477a131a59b36c3
# 87414  cbb68c721ba9ddb30d8a490cc1897fa1  00a39521eb40f7012db50455bf083460
# ...                                 ...                               ...
# 88272  09c682ef897935e677a0996cfe2008f3  ff44401d0d8f5b9c54a47374eb48c1b8
# 92931  62a2c35611e8757e40fbbcecb3c9b2bd  ff8892f7c26aa0446da53d01b18df463
# 79859  d064be88116eb8b958727aec4cf56a59  ff922bdd6bafcdf99cb90d7f39cea5b3
# 75057  1ae563fdfa500d150be6578066d83998  ff922bdd6bafcdf99cb90d7f39cea5b3
# 64323  4b231c90751c27521f7ee27ed2dc3b8f  ffe254cc039740e17dd15a5305035928
#
#        customer_zip_code_prefix customer_city customer_state
# 35608                     45200        jequie             BA
# 22066                     26220   nova iguacu             RJ
# 87012                     57035        maceio             AL
# 61403                     40731      salvador             BA
# 87414                     72595      brasilia             DF
# ...                         ...           ...            ...
# 88272                     13070      campinas             SP
# 92931                     45972       ibiraja             BA
# 79859                     17340  barra bonita             SP
# 75057                     17340  barra bonita             SP
# 64323                     37640       extrema             MG
#
# [3345 rows x 5 columns]

# %%
# Take a look at a couple of ids

customers[customers.customer_unique_id=='ff8892f7c26aa0446da53d01b18df463']
# Out:
#                             customer_id                customer_unique_id  \
# 29670  e53e1eedc9ebf9fa7a3318c60ece1d25  ff8892f7c26aa0446da53d01b18df463
# 92931  62a2c35611e8757e40fbbcecb3c9b2bd  ff8892f7c26aa0446da53d01b18df463
#
#        customer_zip_code_prefix customer_city customer_state
# 29670                     45972       ibiraja             BA
# 92931                     45972       ibiraja             BA

# %%
customers[customers.customer_unique_id=='004288347e5e88a27ded2bb23747066c']
# Out:
#                             customer_id                customer_unique_id  \
# 20023  1b4a75b3478138e99902678254b260f4  004288347e5e88a27ded2bb23747066c
# 22066  f6efe5d5c7b85e12355f9d5c3db46da2  004288347e5e88a27ded2bb23747066c
#
#        customer_zip_code_prefix customer_city customer_state
# 20023                     26220   nova iguacu             RJ
# 22066                     26220   nova iguacu             RJ

# %% [markdown]
# Okay, `customer_unique_id` are actually unique but can be used multiple times if a customer places multiple orders.

# %%
# Check that pairs of customer_id(user id in orders) and customer_unique_id are unique

customers.groupby(['customer_unique_id', 'customer_id'], as_index=False) \
         .agg({'customer_zip_code_prefix':'count'}) \
         .sort_values('customer_zip_code_prefix', ascending=False)
# Out:
#                      customer_unique_id                       customer_id  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2  fadbb3709178fc513abc1b2670aa1ad2
# 66279  aa5acec351a7dcaa930b80dd8ed4da13  b327ddd5ff19aa2c1b93989bfe4486ca
# 66301  aa69091f4d619f53b251229ddc31aa8e  b80ecede4483f7ca92378b5b0903bb6e
# 66300  aa68ea9af3ca240acd9fb5e416ede248  2872db8bee140b1c1f86b8a3647bc83f
# 66299  aa68438532ec59ddec97fa34b08d8e5e  9a51942bc62ef2eb2ca56a830515154a
# ...                                 ...                               ...
# 33144  552fc05a13d28356a38e8b13f64cbe4f  e26479d04765d65d6a871173f38ff5a9
# 33143  552fc05a13d28356a38e8b13f64cbe4f  10b59f56c87c5f68a2dbf3646f0f78bb
# 33142  552fb4b2b8c996ad7615372c99e12ae9  b078a7c9a43c06c915270648b718d931
# 33141  552f9632aafabca9f9013740161f8db2  8e243644561da4b5822473dcaf36a894
# 99440  ffffd2657e2aad2907e67c3e9daecbeb  70bc4d9cf2bbeea3f7b09798370f5884
#
#        customer_zip_code_prefix
# 0                             1
# 66279                         1
# 66301                         1
# 66300                         1
# 66299                         1
# ...                         ...
# 33144                         1
# 33143                         1
# 33142                         1
# 33141                         1
# 99440                         1
#
# [99441 rows x 3 columns]

# %%
# Look at order_items table

order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_describe(order_items, id_col=2)
# Out:
# Shape:(112650, 7)
#
# Value types:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
#
# Duplicated IDs:79699
#
# Missing values:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Summary:
# * `shipping_limit_date` field is object, while should be timestamp;
# * No missing values;
# * Lots of duplicated IDs which is okay because one item can be ordered multiple times.

# %% [markdown]
# Override types of variables containing dates from object to datetime.

# %%
orders[['order_purchase_timestamp', 
                 'order_approved_at',
                 'order_delivered_carrier_date',
                 'order_delivered_customer_date',
                 'order_estimated_delivery_date']] = orders[['order_purchase_timestamp', 
                 'order_approved_at',
                 'order_delivered_carrier_date',
                 'order_delivered_customer_date',
                 'order_estimated_delivery_date']].apply(pd.to_datetime)

# %%
order_items[['shipping_limit_date']] = order_items[['shipping_limit_date']].apply(pd.to_datetime)

# %% [markdown]
# Let's define **purchases** as orders that are neither `canceled` nor `unavailable` and have a timestamp in `order_approved_at` column (so, they are paid).

# %%
# order_approved_at is not NAN

orders_filtered = orders.dropna(subset=['order_approved_at'])

# %%
excluded_statuses = ['canceled', 'unavailable']
orders_filtered = orders_filtered.query('order_status not in @excluded_statuses')

# %%
# Check

orders_filtered.order_status.value_counts()
# Out:
# delivered     96464
# shipped        1107
# invoiced        314
# processing      301
# approved          2
# Name: order_status, dtype: int64

# %% [markdown]
# Data cleaning and preparation is complete. Let's do some exploratory analysis.

# %% [markdown]
# ### 1. How many users purchased only once?

# %%
# As long as customer_id is unique for every order, we won't get enouh information from orders table only
# We need to merge orders table with customers table

# %%
merged_customers = orders_filtered.merge(customers)

# %%
merged_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP

# %%
merged_customers.groupby('customer_unique_id', as_index=False) \
    .agg({'order_id': 'count'}) \
    .rename(columns={'order_id': 'purchases'}) \
    .query('purchases == 1') \
    .shape[0]
# Out:
# 92087

# %% [markdown]
# There are 92,087 users who only made one transaction.

# %% [markdown]
# ### 2. How many orders do not get delivered on average? What are the reasons? Print the detailed information.

# %%
# Create a copy of the orders table, so the will be untouched

not_delivered_orders = orders.copy()

# %%
# Check data types

not_delivered_orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
# Create year and month columns to use them for grouping

not_delivered_orders['order_year'] = not_delivered_orders.order_estimated_delivery_date.dt.year
not_delivered_orders['order_month'] = not_delivered_orders.order_estimated_delivery_date.dt.month

# %%
not_delivered_orders.groupby(['order_year', 'order_month', 'order_status'], as_index=False) \
    .agg({'order_id': 'nunique'}) \
    .pivot(index=['order_year', 'order_month'], columns='order_status', values='order_id') \
    .loc[:, ['canceled', 'unavailable']] \
    .fillna(0).mean()
# Out:
# order_status
# canceled       23.148148
# unavailable    22.555556
# dtype: float64

# %% [markdown]
# There are on average 45 orders that do not get delivered monthly (either canceled or unavailable).

# %% [markdown]
# ### 3. For each product, determine on which day of the week the product is purchased most often.

# %%
# Take a look at the orders data set

orders_filtered.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13
# 2                    2018-09-04
# 3                    2017-12-15
# 4                    2018-02-26

# %%
# Need to merge orders table with order_items table. Taking a look at the columns that need to be dropped

order_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
merged_order_items = orders_filtered.merge(order_items.drop(columns=['order_item_id', 'seller_id',
       'shipping_limit_date', 'price', 'freight_value']))

# %%
merged_order_items
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112081  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112082  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112083  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112084  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112085  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# 0         delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1         delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2         delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3         delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4         delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...             ...                      ...                 ...
# 112081    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 112082    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 112083    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 112084    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 112085    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2018-07-26 14:31:00           2018-08-07 15:27:45
# 2               2018-08-08 13:50:00           2018-08-17 18:06:29
# 3               2017-11-22 13:39:59           2017-12-02 00:28:42
# 4               2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                             ...                           ...
# 112081          2018-02-07 23:22:42           2018-02-28 17:37:56
# 112082          2017-08-28 20:52:26           2017-09-21 11:24:17
# 112083          2018-01-12 15:35:03           2018-01-25 23:32:54
# 112084          2018-01-12 15:35:03           2018-01-25 23:32:54
# 112085          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#        order_estimated_delivery_date                        product_id
# 0                         2017-10-18  87285b34884572647811a353c7ac498a
# 1                         2018-08-13  595fac2a385ac33a80bd5114aec74eb8
# 2                         2018-09-04  aa4383b373c6aca5d8797843e5594415
# 3                         2017-12-15  d0b61bfb1de832b15ba9d266ca96e5b0
# 4                         2018-02-26  65266b2da20d04dbe00c5c2d3bb7859e
# ...                              ...                               ...
# 112081                    2018-03-02  f1d4ce8c6dd66c47bbaa8c6781c2a923
# 112082                    2017-09-27  b80910977a37536adeddd63663f916ad
# 112083                    2018-02-15  d1c427060a0f73f6b889a5c7c61f2ac4
# 112084                    2018-02-15  d1c427060a0f73f6b889a5c7c61f2ac4
# 112085                    2018-04-03  006619bbed68b000c8ba3f8725d5409e
#
# [112086 rows x 9 columns]

# %% [markdown]
# The purchase is complete if the payment has gone through (there is a date in `order_approved_at` column).

# %%
# Add a column with the day of the week
 
merged_order_items['day_of_week'] = merged_order_items['order_approved_at'].dt.strftime("%A")

# %%
# Result table

merged_order_items.groupby(['product_id', 'day_of_week'], as_index=False) \
    .agg({'order_id': 'count'}) \
    .sort_values('order_id', ascending=False) \
    .groupby('product_id') \
    .head(1) \
    .rename(columns={'order_id': 'purchases'})
# Out:
#                              product_id day_of_week  purchases
# 40850  aca2eb7d00ea1a7b8ebd4e68314663af     Tuesday        119
# 20036  53b36df67ebb7c41585e8d54d6772e08     Tuesday        105
# 15844  422879e10f46682990de24d770e7f83d     Tuesday         89
# 36363  99a4788cb24856965c36a24e339b6058     Tuesday         82
# 12996  368c6c730842d78016ad823897a372db    Thursday         80
# ...                                 ...         ...        ...
# 23840  63dfa8b12200610ed7b5e41d3c888a25    Saturday          1
# 23844  63e51e65ec59b56039c6427eed73dcf0     Tuesday          1
# 23845  63eb97106bfe47fe857edcf78f3e3e08    Saturday          1
# 23855  63f52009dc3ddb733394e80183aed0f0    Saturday          1
# 60792  fffe9eeff12fcbd74a2f2b007dde0c58   Wednesday          1
#
# [32726 rows x 3 columns]

# %% [markdown]
# ### 4. Purchases by day of week.

# %%
# Distribution of purchases table 

purchases_by_dow = merged_order_items \
    .groupby('day_of_week', as_index=False) \
    .agg({'order_id':'nunique'}).rename(columns={'order_id': 'unique_orders'}) \
    .sort_values('unique_orders', ascending=False)

purchases_by_dow
# Out:
#   day_of_week  unique_orders
# 5     Tuesday          18936
# 6   Wednesday          15618
# 4    Thursday          15302
# 0      Friday          14500
# 1      Monday          12846
# 2    Saturday          12058
# 3      Sunday           8925

# %%
ax = sns.barplot(x='day_of_week', y='unique_orders', data=purchases_by_dow, palette='rocket')
ax.set(xlabel=None)
ax.set(ylabel=None)

plt.title('Purchases by day of week \n', fontsize = 17)
plt.show()

# %% [markdown]
# TOP-3 most popular days for purchases are Tuesday, Wednesday and Thursday. There are almost twice as fewer purchases on Sunday than on Tuesday.

# %% [markdown]
# ### 5. How many purchases does each user have on average per week (by month)? Considering that there may not be a whole number of weeks within a month.

# %%
# Looking at the data again

merged_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP

# %%
# Create a new columns with month and year of puchase, will group by it later 

merged_customers['purchase_year_month'] = merged_customers.order_approved_at.dt.to_period('M')

# %%
# Number of purchases by customer in every month

purchases_by_month = merged_customers \
    .groupby(['customer_unique_id', 'purchase_year_month'], as_index=False) \
    .agg({'order_id': 'count'}) \
    .rename(columns={'order_id': 'purchases'})

# %%
purchases_by_month
# Out:
#                      customer_unique_id purchase_year_month  purchases
# 0      0000366f3b9a7992bf8c76cfdf3221e2             2018-05          1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f             2018-05          1
# 2      0000f46a3911fa3c0805444483337064             2017-03          1
# 3      0000f6ccb0745a6a4b88665a16c9f078             2017-10          1
# 4      0004aac84e0df4da2b147fca70cf8255             2017-11          1
# ...                                 ...                 ...        ...
# 96841  fffcf5a5ff07b0908bd4e2dbc735a684             2017-06          1
# 96842  fffea47cd6d3cc0a88bd621562a9d061             2017-12          1
# 96843  ffff371b4d645b6ecea244b27531430a             2017-02          1
# 96844  ffff5962728ec6157033ef9805bacc48             2018-05          1
# 96845  ffffd2657e2aad2907e67c3e9daecbeb             2017-05          1
#
# [96846 rows x 3 columns]

# %%
# Function to calculate the amount of weeks in each month

def weeks_in_month(date):
    year = date.year
    month = date.month
    days_in_month = calendar.monthrange(year, month)[1]
    return round(days_in_month / 7, 2)

# %%
# New column with the amount of weeks 

purchases_by_month['weeks_in_month'] = purchases_by_month \
    .purchase_year_month.apply(lambda x: weeks_in_month(x))

# %%
# Look at the result

purchases_by_month.sort_values('purchases')
# Out:
#                      customer_unique_id purchase_year_month  purchases  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2             2018-05          1
# 64358  a9dd5adb51c5a1a637afbebf0dd554be             2018-04          1
# 64357  a9dd2b5b5bd99f1475a6bfc3b5837efc             2017-10          1
# 64356  a9db167d8824c6068bf31c6858dc2a11             2018-04          1
# 64355  a9da5a115fdd7b13412153e54dc02604             2018-04          1
# ...                                 ...                 ...        ...
# 68541  b4e4f24de1e8725b74e4a1f4975116ed             2018-02          4
# 23648  3e43e6105506432c953e165fb2acf44c             2018-02          4
# 14310  25a560b9a6006157838aab1bdbd68624             2017-04          4
# 61437  a239b8e2fbce33780f1f1912e2ee5275             2017-02          4
# 7232   12f5d6e1cbf93dafd9dcc19095df0b3d             2017-01          6
#
#        weeks_in_month
# 0                4.43
# 64358            4.29
# 64357            4.43
# 64356            4.29
# 64355            4.29
# ...               ...
# 68541            4.00
# 23648            4.00
# 14310            4.29
# 61437            4.00
# 7232             4.43
#
# [96846 rows x 4 columns]

# %%
# Average purchases per week

purchases_by_month['purchases_per_week'] = purchases_by_month.purchases / purchases_by_month.weeks_in_month
purchases_by_month
# Out:
#                      customer_unique_id purchase_year_month  purchases  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2             2018-05          1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f             2018-05          1
# 2      0000f46a3911fa3c0805444483337064             2017-03          1
# 3      0000f6ccb0745a6a4b88665a16c9f078             2017-10          1
# 4      0004aac84e0df4da2b147fca70cf8255             2017-11          1
# ...                                 ...                 ...        ...
# 96841  fffcf5a5ff07b0908bd4e2dbc735a684             2017-06          1
# 96842  fffea47cd6d3cc0a88bd621562a9d061             2017-12          1
# 96843  ffff371b4d645b6ecea244b27531430a             2017-02          1
# 96844  ffff5962728ec6157033ef9805bacc48             2018-05          1
# 96845  ffffd2657e2aad2907e67c3e9daecbeb             2017-05          1
#
#        weeks_in_month  purchases_per_week
# 0                4.43            0.225734
# 1                4.43            0.225734
# 2                4.43            0.225734
# 3                4.43            0.225734
# 4                4.29            0.233100
# ...               ...                 ...
# 96841            4.29            0.233100
# 96842            4.43            0.225734
# 96843            4.00            0.250000
# 96844            4.43            0.225734
# 96845            4.43            0.225734
#
# [96846 rows x 5 columns]

# %% [markdown]
# Let's plot the result and check whether there are any differences in purchases between months.

# %%
# Take avg of purchases per month

a = purchases_by_month.groupby('purchase_year_month', as_index=False) \
        .agg({'purchases_per_week': 'mean'})

# %%
sns.set(rc={'figure.figsize':(20,7)})

ax = sns.barplot(x='purchase_year_month', y='purchases_per_week', data=a, palette='rocket')

ax.set(xlabel=None)
ax.set(ylabel=None)
plt.xticks(rotation=30)
plt.title('Average purchases per week by month \n', fontsize = 17)
plt.show()

# %% [markdown]
# Generally, there are no seasonal fluctuations and sales are almost equally spread throughout the whole period of observation. There are two spikes in February but it's probably because there are less weeks in February.

# %% [markdown]
# ### 6. Conduct a cohort analysis of users. From January to December identify the cohort with the highest retention for the 3rd month.

# %%
# Sneak peek at the data again

merged_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#   purchase_year_month
# 0             2017-10
# 1             2018-07
# 2             2018-08
# 3             2017-11
# 4             2018-02

# %%
cohort_analysis = merged_customers.copy()

# %%
# Look at the distribution of purchases by year-month

cohort_analysis.purchase_year_month.value_counts()
# Out:
# 2017-11    7280
# 2018-03    7249
# 2018-01    7108
# 2018-05    7026
# 2018-04    6758
# 2018-02    6604
# 2018-08    6575
# 2018-06    6142
# 2018-07    6125
# 2017-12    5782
# 2017-10    4512
# 2017-08    4296
# 2017-09    4248
# 2017-07    3899
# 2017-05    3642
# 2017-06    3214
# 2017-03    2626
# 2017-04    2352
# 2017-02    1703
# 2017-01     750
# 2016-10     294
# 2016-09       1
# 2018-09       1
# 2016-12       1
# Freq: M, Name: purchase_year_month, dtype: int64

# %%
# Customers cohort will be defined by the date of their first purchase

cohort_analysis['first_purchase_date'] = cohort_analysis \
    .groupby('customer_unique_id')['purchase_year_month'] \
    .transform('min')

# %%
cohort_analysis
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98183  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98184  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98185  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98186  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98187  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...            ...                      ...                 ...
# 98183    delivered      2017-03-09 09:54:05 2017-03-09 09:54:05
# 98184    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 98185    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 98186    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 98187    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 98183          2017-03-10 11:18:03           2017-03-17 15:08:01
# 98184          2018-02-07 23:22:42           2018-02-28 17:37:56
# 98185          2017-08-28 20:52:26           2017-09-21 11:24:17
# 98186          2018-01-12 15:35:03           2018-01-25 23:32:54
# 98187          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0                        2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                        2018-08-13  af07308b275d755c9edb36a90c618231
# 2                        2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                        2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                        2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 98183                    2017-03-28  6359f309b166b0196dbf7ad2ac62bb5a
# 98184                    2018-03-02  da62f9e57a76d978d02ab5362c509660
# 98185                    2017-09-27  737520a9aad80b3fbbdad19b66b37b30
# 98186                    2018-02-15  5097a5312c8b157bb7be58ae360ef43c
# 98187                    2018-04-03  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 98183                     12209      sao jose dos campos             SP
# 98184                     11722             praia grande             SP
# 98185                     45920              nova vicosa             BA
# 98186                     28685                  japuiba             RJ
# 98187                     83750                     lapa             PR
#
#       purchase_year_month first_purchase_date
# 0                 2017-10             2017-09
# 1                 2018-07             2018-07
# 2                 2018-08             2018-08
# 3                 2017-11             2017-11
# 4                 2018-02             2018-02
# ...                   ...                 ...
# 98183             2017-03             2017-03
# 98184             2018-02             2018-02
# 98185             2017-08             2017-08
# 98186             2018-01             2018-01
# 98187             2018-03             2018-03
#
# [98188 rows x 14 columns]

# %%
# Month difference between the first purchase and the current one

cohort_analysis['months_diff'] = cohort_analysis['purchase_year_month'] \
                                    .subtract(cohort_analysis['first_purchase_date']) \
                                    .apply(lambda x: x.n)

# %%
cohort_analysis
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98183  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98184  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98185  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98186  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98187  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...            ...                      ...                 ...
# 98183    delivered      2017-03-09 09:54:05 2017-03-09 09:54:05
# 98184    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 98185    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 98186    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 98187    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 98183          2017-03-10 11:18:03           2017-03-17 15:08:01
# 98184          2018-02-07 23:22:42           2018-02-28 17:37:56
# 98185          2017-08-28 20:52:26           2017-09-21 11:24:17
# 98186          2018-01-12 15:35:03           2018-01-25 23:32:54
# 98187          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0                        2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                        2018-08-13  af07308b275d755c9edb36a90c618231
# 2                        2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                        2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                        2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 98183                    2017-03-28  6359f309b166b0196dbf7ad2ac62bb5a
# 98184                    2018-03-02  da62f9e57a76d978d02ab5362c509660
# 98185                    2017-09-27  737520a9aad80b3fbbdad19b66b37b30
# 98186                    2018-02-15  5097a5312c8b157bb7be58ae360ef43c
# 98187                    2018-04-03  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 98183                     12209      sao jose dos campos             SP
# 98184                     11722             praia grande             SP
# 98185                     45920              nova vicosa             BA
# 98186                     28685                  japuiba             RJ
# 98187                     83750                     lapa             PR
#
#       purchase_year_month first_purchase_date  months_diff
# 0                 2017-10             2017-09            1
# 1                 2018-07             2018-07            0
# 2                 2018-08             2018-08            0
# 3                 2017-11             2017-11            0
# 4                 2018-02             2018-02            0
# ...                   ...                 ...          ...
# 98183             2017-03             2017-03            0
# 98184             2018-02             2018-02            0
# 98185             2017-08             2017-08            0
# 98186             2018-01             2018-01            0
# 98187             2018-03             2018-03            0
#
# [98188 rows x 15 columns]

# %%
# Define customer cohort by the first purchase, count the amount of customers purchasing in every subsequent month

cohort_table = cohort_analysis \
    .pivot_table(index='first_purchase_date',
                 columns='months_diff',
                 values='customer_unique_id',
                 aggfunc='nunique')

cohort_table
# Out:
# months_diff              0     1     2     3     4     5     6     7     8   \
# first_purchase_date
# 2016-09                 1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-10               291.0   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN
# 2016-12                 1.0   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-01               716.0   4.0   2.0   1.0   3.0   1.0   3.0   1.0   1.0
# 2017-02              1674.0   4.0   4.0   3.0   7.0   2.0   4.0   3.0   1.0
# 2017-03              2580.0  13.0   9.0   9.0   9.0   4.0   4.0   8.0   8.0
# 2017-04              2301.0  14.0   5.0   4.0   6.0   6.0   8.0   6.0   8.0
# 2017-05              3543.0  19.0  17.0  14.0  11.0  12.0  15.0   5.0   9.0
# 2017-06              3110.0  14.0  11.0  12.0   8.0  11.0  11.0   7.0   4.0
# 2017-07              3776.0  20.0  12.0   7.0  13.0   7.0  12.0   4.0   7.0
# 2017-08              4154.0  28.0  15.0  11.0  16.0  22.0  11.0  11.0   5.0
# 2017-09              4097.0  27.0  20.0  14.0  17.0  11.0   9.0   9.0  13.0
# 2017-10              4360.0  30.0  13.0   4.0  10.0   8.0  11.0  16.0  12.0
# 2017-11              7053.0  39.0  27.0  11.0  14.0  11.0   9.0  14.0   8.0
# 2017-12              5591.0  13.0  15.0  18.0  13.0  11.0   9.0   1.0  12.0
# 2018-01              6878.0  24.0  26.0  20.0  22.0  11.0  12.0  15.0   NaN
# 2018-02              6335.0  21.0  25.0  18.0  17.0  11.0  14.0   NaN   NaN
# 2018-03              7009.0  28.0  23.0  20.0  10.0   9.0   NaN   NaN   NaN
# 2018-04              6542.0  39.0  19.0  16.0   9.0   NaN   NaN   NaN   NaN
# 2018-05              6774.0  37.0  17.0  14.0   NaN   NaN   NaN   NaN   NaN
# 2018-06              5916.0  23.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2018-07              5915.0  30.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2018-08              6356.0   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# months_diff           9     10    11   12    13   14   15   16   17   19   20
# first_purchase_date
# 2016-09              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2016-10              1.0   NaN   1.0  NaN   1.0  NaN  1.0  NaN  1.0  2.0  2.0
# 2016-12              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-01              NaN   2.0   2.0  5.0   3.0  1.0  1.0  2.0  3.0  1.0  NaN
# 2017-02              3.0   2.0   5.0  2.0   3.0  2.0  1.0  1.0  4.0  NaN  NaN
# 2017-03              3.0  10.0   3.0  6.0   3.0  4.0  6.0  2.0  4.0  NaN  NaN
# 2017-04              4.0   5.0   2.0  2.0   1.0  2.0  2.0  3.0  NaN  NaN  NaN
# 2017-05              9.0  10.0  12.0  7.0   2.0  7.0  8.0  NaN  NaN  NaN  NaN
# 2017-06              7.0  10.0  11.0  5.0   4.0  6.0  NaN  NaN  NaN  NaN  NaN
# 2017-07              9.0   8.0  11.0  5.0  10.0  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-08              7.0  10.0   7.0  6.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-09              7.0  11.0   3.0  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-10              9.0   9.0   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-11              5.0   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2017-12              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-01              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-02              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-03              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-04              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-05              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-06              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-07              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2018-08              NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Use purchases in month 0 to calculate percentages

divisor = cohort_table.iloc[:,0]

# %%
retention = cohort_table.divide(divisor, axis='index') 
retention
# Out:
# months_diff           0         1         2         3         4         5   \
# first_purchase_date
# 2016-09              1.0       NaN       NaN       NaN       NaN       NaN
# 2016-10              1.0       NaN       NaN       NaN       NaN       NaN
# 2016-12              1.0  1.000000       NaN       NaN       NaN       NaN
# 2017-01              1.0  0.005587  0.002793  0.001397  0.004190  0.001397
# 2017-02              1.0  0.002389  0.002389  0.001792  0.004182  0.001195
# 2017-03              1.0  0.005039  0.003488  0.003488  0.003488  0.001550
# 2017-04              1.0  0.006084  0.002173  0.001738  0.002608  0.002608
# 2017-05              1.0  0.005363  0.004798  0.003951  0.003105  0.003387
# 2017-06              1.0  0.004502  0.003537  0.003859  0.002572  0.003537
# 2017-07              1.0  0.005297  0.003178  0.001854  0.003443  0.001854
# 2017-08              1.0  0.006740  0.003611  0.002648  0.003852  0.005296
# 2017-09              1.0  0.006590  0.004882  0.003417  0.004149  0.002685
# 2017-10              1.0  0.006881  0.002982  0.000917  0.002294  0.001835
# 2017-11              1.0  0.005530  0.003828  0.001560  0.001985  0.001560
# 2017-12              1.0  0.002325  0.002683  0.003219  0.002325  0.001967
# 2018-01              1.0  0.003489  0.003780  0.002908  0.003199  0.001599
# 2018-02              1.0  0.003315  0.003946  0.002841  0.002684  0.001736
# 2018-03              1.0  0.003995  0.003281  0.002853  0.001427  0.001284
# 2018-04              1.0  0.005961  0.002904  0.002446  0.001376       NaN
# 2018-05              1.0  0.005462  0.002510  0.002067       NaN       NaN
# 2018-06              1.0  0.003888  0.002705       NaN       NaN       NaN
# 2018-07              1.0  0.005072       NaN       NaN       NaN       NaN
# 2018-08              1.0  0.000157       NaN       NaN       NaN       NaN
#
# months_diff                6         7         8         9         10  \
# first_purchase_date
# 2016-09                   NaN       NaN       NaN       NaN       NaN
# 2016-10              0.003436       NaN       NaN  0.003436       NaN
# 2016-12                   NaN       NaN       NaN       NaN       NaN
# 2017-01              0.004190  0.001397  0.001397       NaN  0.002793
# 2017-02              0.002389  0.001792  0.000597  0.001792  0.001195
# 2017-03              0.001550  0.003101  0.003101  0.001163  0.003876
# 2017-04              0.003477  0.002608  0.003477  0.001738  0.002173
# 2017-05              0.004234  0.001411  0.002540  0.002540  0.002822
# 2017-06              0.003537  0.002251  0.001286  0.002251  0.003215
# 2017-07              0.003178  0.001059  0.001854  0.002383  0.002119
# 2017-08              0.002648  0.002648  0.001204  0.001685  0.002407
# 2017-09              0.002197  0.002197  0.003173  0.001709  0.002685
# 2017-10              0.002523  0.003670  0.002752  0.002064  0.002064
# 2017-11              0.001276  0.001985  0.001134  0.000709       NaN
# 2017-12              0.001610  0.000179  0.002146       NaN       NaN
# 2018-01              0.001745  0.002181       NaN       NaN       NaN
# 2018-02              0.002210       NaN       NaN       NaN       NaN
# 2018-03                   NaN       NaN       NaN       NaN       NaN
# 2018-04                   NaN       NaN       NaN       NaN       NaN
# 2018-05                   NaN       NaN       NaN       NaN       NaN
# 2018-06                   NaN       NaN       NaN       NaN       NaN
# 2018-07                   NaN       NaN       NaN       NaN       NaN
# 2018-08                   NaN       NaN       NaN       NaN       NaN
#
# months_diff                11        12        13        14        15  \
# first_purchase_date
# 2016-09                   NaN       NaN       NaN       NaN       NaN
# 2016-10              0.003436       NaN  0.003436       NaN  0.003436
# 2016-12                   NaN       NaN       NaN       NaN       NaN
# 2017-01              0.002793  0.006983  0.004190  0.001397  0.001397
# 2017-02              0.002987  0.001195  0.001792  0.001195  0.000597
# 2017-03              0.001163  0.002326  0.001163  0.001550  0.002326
# 2017-04              0.000869  0.000869  0.000435  0.000869  0.000869
# 2017-05              0.003387  0.001976  0.000564  0.001976  0.002258
# 2017-06              0.003537  0.001608  0.001286  0.001929       NaN
# 2017-07              0.002913  0.001324  0.002648       NaN       NaN
# 2017-08              0.001685  0.001444       NaN       NaN       NaN
# 2017-09              0.000732       NaN       NaN       NaN       NaN
# 2017-10                   NaN       NaN       NaN       NaN       NaN
# 2017-11                   NaN       NaN       NaN       NaN       NaN
# 2017-12                   NaN       NaN       NaN       NaN       NaN
# 2018-01                   NaN       NaN       NaN       NaN       NaN
# 2018-02                   NaN       NaN       NaN       NaN       NaN
# 2018-03                   NaN       NaN       NaN       NaN       NaN
# 2018-04                   NaN       NaN       NaN       NaN       NaN
# 2018-05                   NaN       NaN       NaN       NaN       NaN
# 2018-06                   NaN       NaN       NaN       NaN       NaN
# 2018-07                   NaN       NaN       NaN       NaN       NaN
# 2018-08                   NaN       NaN       NaN       NaN       NaN
#
# months_diff                16        17        19        20
# first_purchase_date
# 2016-09                   NaN       NaN       NaN       NaN
# 2016-10                   NaN  0.003436  0.006873  0.006873
# 2016-12                   NaN       NaN       NaN       NaN
# 2017-01              0.002793  0.004190  0.001397       NaN
# 2017-02              0.000597  0.002389       NaN       NaN
# 2017-03              0.000775  0.001550       NaN       NaN
# 2017-04              0.001304       NaN       NaN       NaN
# 2017-05                   NaN       NaN       NaN       NaN
# 2017-06                   NaN       NaN       NaN       NaN
# 2017-07                   NaN       NaN       NaN       NaN
# 2017-08                   NaN       NaN       NaN       NaN
# 2017-09                   NaN       NaN       NaN       NaN
# 2017-10                   NaN       NaN       NaN       NaN
# 2017-11                   NaN       NaN       NaN       NaN
# 2017-12                   NaN       NaN       NaN       NaN
# 2018-01                   NaN       NaN       NaN       NaN
# 2018-02                   NaN       NaN       NaN       NaN
# 2018-03                   NaN       NaN       NaN       NaN
# 2018-04                   NaN       NaN       NaN       NaN
# 2018-05                   NaN       NaN       NaN       NaN
# 2018-06                   NaN       NaN       NaN       NaN
# 2018-07                   NaN       NaN       NaN       NaN
# 2018-08                   NaN       NaN       NaN       NaN

# %%
# Filter one full year

retention = retention.loc['2017-01': '2017-12']

# %%
# Converting to percentages

retention.round(4)*100
# Out:
# months_diff             0     1     2     3     4     5     6     7     8   \
# first_purchase_date
# 2017-01              100.0  0.56  0.28  0.14  0.42  0.14  0.42  0.14  0.14
# 2017-02              100.0  0.24  0.24  0.18  0.42  0.12  0.24  0.18  0.06
# 2017-03              100.0  0.50  0.35  0.35  0.35  0.16  0.16  0.31  0.31
# 2017-04              100.0  0.61  0.22  0.17  0.26  0.26  0.35  0.26  0.35
# 2017-05              100.0  0.54  0.48  0.40  0.31  0.34  0.42  0.14  0.25
# 2017-06              100.0  0.45  0.35  0.39  0.26  0.35  0.35  0.23  0.13
# 2017-07              100.0  0.53  0.32  0.19  0.34  0.19  0.32  0.11  0.19
# 2017-08              100.0  0.67  0.36  0.26  0.39  0.53  0.26  0.26  0.12
# 2017-09              100.0  0.66  0.49  0.34  0.41  0.27  0.22  0.22  0.32
# 2017-10              100.0  0.69  0.30  0.09  0.23  0.18  0.25  0.37  0.28
# 2017-11              100.0  0.55  0.38  0.16  0.20  0.16  0.13  0.20  0.11
# 2017-12              100.0  0.23  0.27  0.32  0.23  0.20  0.16  0.02  0.21
#
# months_diff            9     10    11    12    13    14    15    16    17  \
# first_purchase_date
# 2017-01               NaN  0.28  0.28  0.70  0.42  0.14  0.14  0.28  0.42
# 2017-02              0.18  0.12  0.30  0.12  0.18  0.12  0.06  0.06  0.24
# 2017-03              0.12  0.39  0.12  0.23  0.12  0.16  0.23  0.08  0.16
# 2017-04              0.17  0.22  0.09  0.09  0.04  0.09  0.09  0.13   NaN
# 2017-05              0.25  0.28  0.34  0.20  0.06  0.20  0.23   NaN   NaN
# 2017-06              0.23  0.32  0.35  0.16  0.13  0.19   NaN   NaN   NaN
# 2017-07              0.24  0.21  0.29  0.13  0.26   NaN   NaN   NaN   NaN
# 2017-08              0.17  0.24  0.17  0.14   NaN   NaN   NaN   NaN   NaN
# 2017-09              0.17  0.27  0.07   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-10              0.21  0.21   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-11              0.07   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-12               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# months_diff            19  20
# first_purchase_date
# 2017-01              0.14 NaN
# 2017-02               NaN NaN
# 2017-03               NaN NaN
# 2017-04               NaN NaN
# 2017-05               NaN NaN
# 2017-06               NaN NaN
# 2017-07               NaN NaN
# 2017-08               NaN NaN
# 2017-09               NaN NaN
# 2017-10               NaN NaN
# 2017-11               NaN NaN
# 2017-12               NaN NaN

# %%
# Visualisation

plt.figure(figsize=(25, 12))

ax = sns.heatmap(retention, annot=True, fmt= '.2%', vmin = 0.0 , vmax = 0.006)

ax.set(xlabel='Cohort Index')
ax.set(ylabel='Cohort Month \n')
plt.title('Retention Rate in percentage: Monthly Cohorts \n', fontsize = 17)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# The highest retention in the third month is in the cohort 2017-05 and amounted to 0.40%.

# %% [markdown]
# ### 7. Build RFM segmentation of users to evaluate your audience qualitatively.
#
# #### Let R be the time from the user's last purchase to the current date, <br> F be the total number of purchases of the user, <br> M be the sum of money spent.

# %%
# Sneak peek at the data

merged_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0                    2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                    2018-08-13  af07308b275d755c9edb36a90c618231
# 2                    2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                    2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                    2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state  \
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP
#
#   purchase_year_month
# 0             2017-10
# 1             2018-07
# 2             2018-08
# 3             2017-11
# 4             2018-02

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# 4 2017-02-13 13:57:51  199.90          18.14

# %%
# Since we do not have data on the number of goods in each order (there is only the sequence number of the 
# goods in the order - order_item_id), first we will find the amount of a certain product in a particular 
# order and its price 

# NB the price of the product varies from order to order due to promo codes, personal discounts, 
# price changes over time and etc.


sold_per_order = order_items.groupby(['order_id', 'product_id', 'price'], as_index=False) \
    .agg({'order_item_id': 'count'}) \
    .rename(columns={'order_item_id': 'amount'})

# %%
sold_per_order
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#          price  amount
# 0        58.90       1
# 1       239.90       1
# 2       199.00       1
# 3        12.99       1
# 4       199.90       1
# ...        ...     ...
# 102420  299.99       1
# 102421  350.00       1
# 102422   99.90       1
# 102423   55.99       1
# 102424   43.00       1
#
# [102425 rows x 4 columns]

# %%
sold_per_order['total'] = sold_per_order.amount * sold_per_order.price

# %%
# Find the total sum for each order

sold_per_order = sold_per_order.groupby(['order_id'], as_index=False) \
                 .agg({'total': 'sum'}) \
                 .rename(columns={'total': 'total_sum_order'}) 

sold_per_order
# Out:
#                                order_id  total_sum_order
# 0      00010242fe8c5a6d1ba2dd792cb16214            58.90
# 1      00018f77f2f0320c557190d7a144bdd3           239.90
# 2      000229ec398224ef6ca0657da4fc703e           199.00
# 3      00024acbcdf0a6daa1e931b038114c75            12.99
# 4      00042b26cf59d7ce69dfabb4e55b4fd9           199.90
# ...                                 ...              ...
# 98661  fffc94f6ce00a00581880bf54a75a037           299.99
# 98662  fffcd46ef2263f404302a634eb57f7eb           350.00
# 98663  fffce4705a9662cd70adb13d4a31832d            99.90
# 98664  fffe18544ffabc95dfada21779c9644f            55.99
# 98665  fffe41c64501cc87c801fd61db3f6244            43.00
#
# [98666 rows x 2 columns]

# %%
# Merge items table with orders+customers table

rfm_analysis = merged_customers.merge(sold_per_order)
rfm_analysis
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98180  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98181  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98182  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98183  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98184  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...            ...                      ...                 ...
# 98180    delivered      2017-03-09 09:54:05 2017-03-09 09:54:05
# 98181    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 98182    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 98183    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 98184    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 98180          2017-03-10 11:18:03           2017-03-17 15:08:01
# 98181          2018-02-07 23:22:42           2018-02-28 17:37:56
# 98182          2017-08-28 20:52:26           2017-09-21 11:24:17
# 98183          2018-01-12 15:35:03           2018-01-25 23:32:54
# 98184          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0                        2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                        2018-08-13  af07308b275d755c9edb36a90c618231
# 2                        2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                        2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                        2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 98180                    2017-03-28  6359f309b166b0196dbf7ad2ac62bb5a
# 98181                    2018-03-02  da62f9e57a76d978d02ab5362c509660
# 98182                    2017-09-27  737520a9aad80b3fbbdad19b66b37b30
# 98183                    2018-02-15  5097a5312c8b157bb7be58ae360ef43c
# 98184                    2018-04-03  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 98180                     12209      sao jose dos campos             SP
# 98181                     11722             praia grande             SP
# 98182                     45920              nova vicosa             BA
# 98183                     28685                  japuiba             RJ
# 98184                     83750                     lapa             PR
#
#       purchase_year_month  total_sum_order
# 0                 2017-10            29.99
# 1                 2018-07           118.70
# 2                 2018-08           159.90
# 3                 2017-11            45.00
# 4                 2018-02            19.90
# ...                   ...              ...
# 98180             2017-03            72.00
# 98181             2018-02           174.90
# 98182             2017-08           205.99
# 98183             2018-01           359.98
# 98184             2018-03            68.50
#
# [98185 rows x 14 columns]

# %%
# To measure Recency in RFM analysis, we need to select some date for the reference point. If the data were fresh,
# then we could take the current date, but since the last record is older than 3 years, we will take the last date 
# in the dataset + 3 days. It will be the reference point.

TODAY = rfm_analysis['order_approved_at'].max() + timedelta(days=3)

# %%
TODAY
# Out:
# Timestamp('2018-09-06 17:40:06')

# %%
# Add new column with the amount of days since the current purchase

rfm_analysis['days_since_order'] = (TODAY - rfm_analysis.order_approved_at).dt.days
rfm_analysis
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 98180  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 98181  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 98182  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 98183  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 98184  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 0        delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
# ...            ...                      ...                 ...
# 98180    delivered      2017-03-09 09:54:05 2017-03-09 09:54:05
# 98181    delivered      2018-02-06 12:58:58 2018-02-06 13:10:37
# 98182    delivered      2017-08-27 14:46:43 2017-08-27 15:04:16
# 98183    delivered      2018-01-08 21:28:27 2018-01-08 21:36:21
# 98184    delivered      2018-03-08 20:57:30 2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 98180          2017-03-10 11:18:03           2017-03-17 15:08:01
# 98181          2018-02-07 23:22:42           2018-02-28 17:37:56
# 98182          2017-08-28 20:52:26           2017-09-21 11:24:17
# 98183          2018-01-12 15:35:03           2018-01-25 23:32:54
# 98184          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0                        2017-10-18  7c396fd4830fd04220f754e42b4e5bff
# 1                        2018-08-13  af07308b275d755c9edb36a90c618231
# 2                        2018-09-04  3a653a41f6f9fc3d2a113cf8398680e8
# 3                        2017-12-15  7c142cf63193a1473d2e66489a9ae977
# 4                        2018-02-26  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 98180                    2017-03-28  6359f309b166b0196dbf7ad2ac62bb5a
# 98181                    2018-03-02  da62f9e57a76d978d02ab5362c509660
# 98182                    2017-09-27  737520a9aad80b3fbbdad19b66b37b30
# 98183                    2018-02-15  5097a5312c8b157bb7be58ae360ef43c
# 98184                    2018-04-03  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 98180                     12209      sao jose dos campos             SP
# 98181                     11722             praia grande             SP
# 98182                     45920              nova vicosa             BA
# 98183                     28685                  japuiba             RJ
# 98184                     83750                     lapa             PR
#
#       purchase_year_month  total_sum_order  days_since_order
# 0                 2017-10            29.99               339
# 1                 2018-07           118.70                42
# 2                 2018-08           159.90                29
# 3                 2017-11            45.00               291
# 4                 2018-02            19.90               204
# ...                   ...              ...               ...
# 98180             2017-03            72.00               546
# 98181             2018-02           174.90               212
# 98182             2017-08           205.99               375
# 98183             2018-01           359.98               240
# 98184             2018-03            68.50               181
#
# [98185 rows x 15 columns]

# %%
# Final table 
# For Recency take the latest order (least number of days since purchase)
# For Frequency - the amount of all orders by the customer
# For Monetary - sum of all purchases

rfm = rfm_analysis.groupby('customer_unique_id', as_index=False) \
            .agg({'days_since_order': 'min', 
                  'order_id': 'count',
                  'total_sum_order': 'sum'}) \
            .rename(columns={'days_since_order': 'recency', 
                             'order_id': 'frequency',
                             'total_sum_order': 'monetary'})

# %%
rfm
# Out:
#                      customer_unique_id  recency  frequency  monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2      119          1    129.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      121          1     18.90
# 2      0000f46a3911fa3c0805444483337064      544          1     69.00
# 3      0000f6ccb0745a6a4b88665a16c9f078      328          1     25.99
# 4      0004aac84e0df4da2b147fca70cf8255      295          1    180.00
# ...                                 ...      ...        ...       ...
# 94965  fffcf5a5ff07b0908bd4e2dbc735a684      454          1   1570.00
# 94966  fffea47cd6d3cc0a88bd621562a9d061      269          1     64.89
# 94967  ffff371b4d645b6ecea244b27531430a      576          1     89.90
# 94968  ffff5962728ec6157033ef9805bacc48      127          1    115.00
# 94969  ffffd2657e2aad2907e67c3e9daecbeb      491          1     56.99
#
# [94970 rows x 4 columns]

# %% [markdown]
# Now let's define the limits for each segment. I want those limits to be adaptive, so instead
# of absolute values I will use relative quantiles.
# <br>Each quantile will contain a third of the sample.

# %%
rfm.describe()
# Out:
#             recency     frequency      monetary
# count  94970.000000  94970.000000  94970.000000
# mean     245.475519      1.033853    142.073605
# std      152.952043      0.210801    216.085833
# min        3.000000      1.000000      0.850000
# 25%      121.000000      1.000000     47.900000
# 50%      226.000000      1.000000     89.890000
# 75%      354.000000      1.000000    155.000000
# max      721.000000     16.000000  13440.000000

# %% [markdown]
# It seems that not all limits can be set based on quantiles. For frequency, the boundaries of all three quantiles coincide. They will have to be set manually, hence they will be absolute and not relative.

# %%
# Recency quantiles

rfm['R'] = pd.qcut(rfm.recency, 3, labels=['1', '2', '3'])

# %%
# Frequency

# 96% of all customers bought only once
# 2.7% - 2 times
# 1.3% - more than 2

rfm.frequency.value_counts(normalize=True)
# Out:
# 1     0.969611
# 2     0.027904
# 3     0.001980
# 4     0.000305
# 5     0.000095
# 6     0.000053
# 7     0.000032
# 16    0.000011
# 9     0.000011
# Name: frequency, dtype: float64

# %% [markdown]
# Since we have such rare purchases (48 times fewer customers make the second order, and ~ 10 times
# fewer make the third), each subsequent purchase has a high weight for us and it is worth placing
# the boundaries of clusters as follows: 1, 2, 2+. In this case, 2+ cluster will be very important
# to us, because they will be those rare 1% of buyers.

# %%
# Frequency groups (set manually)

rfm['F'] = pd.cut(rfm.frequency, bins=[0, 1, 2, 30], labels=['1', '2', '3'])

# %%
# Monetary quantiles

rfm['M'] = pd.qcut(rfm.monetary, 3, labels=['1', '2', '3'])

# %%
# Define the final RFM

rfm['RFM'] = rfm['R'].astype(str) + \
             rfm['F'].astype(str) + \
             rfm['M'].astype(str)

# %%
rfm
# Out:
#                      customer_unique_id  recency  frequency  monetary  R  F  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      119          1    129.90  1  1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      121          1     18.90  1  1
# 2      0000f46a3911fa3c0805444483337064      544          1     69.00  3  1
# 3      0000f6ccb0745a6a4b88665a16c9f078      328          1     25.99  3  1
# 4      0004aac84e0df4da2b147fca70cf8255      295          1    180.00  2  1
# ...                                 ...      ...        ...       ... .. ..
# 94965  fffcf5a5ff07b0908bd4e2dbc735a684      454          1   1570.00  3  1
# 94966  fffea47cd6d3cc0a88bd621562a9d061      269          1     64.89  2  1
# 94967  ffff371b4d645b6ecea244b27531430a      576          1     89.90  3  1
# 94968  ffff5962728ec6157033ef9805bacc48      127          1    115.00  1  1
# 94969  ffffd2657e2aad2907e67c3e9daecbeb      491          1     56.99  3  1
#
#        M  RFM
# 0      3  113
# 1      1  111
# 2      2  312
# 3      1  311
# 4      3  213
# ...   ..  ...
# 94965  3  313
# 94966  2  212
# 94967  2  312
# 94968  2  112
# 94969  1  311
#
# [94970 rows x 8 columns]

# %%
rfm.RFM.value_counts()
# Out:
# 211    10708
# 312    10523
# 311    10427
# 112    10406
# 111    10401
# 113     9986
# 212     9928
# 213     9885
# 313     9820
# 223      638
# 123      637
# 323      490
# 122      241
# 322      227
# 222      224
# 133       96
# 321       69
# 121       65
# 221       59
# 233       53
# 333       51
# 132       13
# 232        9
# 332        7
# 331        6
# 231        1
# Name: RFM, dtype: int64

# %% [markdown]
# Let's define the segments:
# * `Top customers` - active, many purchases, large sums of orders
# * `Active customers` — constantly generate income
# * `Emerging customers` – potential for cross-selling and additional sales
# * `Unsteady customers` – potential for cross-selling and additional sales depending on the offer
# * `Customers at risk` – inactive, but quite frequent and bring high income
#
# Potentially lost customers:
# * `Inactive customers` – rare, but high income
# * `Lost customers` - inactive, rare, low income

# %%
# Dictionary with segments

segments = {'Top customers': ['111', '121', '112', '122'],
            'Active customers': ['131', '132', '113', '123', '133', '114', '124', '134'],
            'Emerging customers': ['211', '221', '231', '212', '222', '232'],
            'Unsteady customers': ['141', '142', '143', '144', '241', '242', '213', '223', '233',
                                   '243', '214', '224', '234', '244'],
            'Customers at risk': ['311', '312', '313', '314', '321', '322', '323', '324', '331',
                                  '332', '341', '342', '411', '412', '413', '414', '421', '422', '423', '424'],
            'Potential lost customers': ['333', '334', '343', '344'],
            'Inactive customers': ['441', '442'],
            'Lost customers': ['443', '444']}

# %%
def segmentation(rfm):
    for key, value in segments.items():
        if rfm in value:
            return key

# %%
rfm['segment'] = rfm['RFM'].apply(segmentation)
rfm
# Out:
#                      customer_unique_id  recency  frequency  monetary  R  F  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      119          1    129.90  1  1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      121          1     18.90  1  1
# 2      0000f46a3911fa3c0805444483337064      544          1     69.00  3  1
# 3      0000f6ccb0745a6a4b88665a16c9f078      328          1     25.99  3  1
# 4      0004aac84e0df4da2b147fca70cf8255      295          1    180.00  2  1
# ...                                 ...      ...        ...       ... .. ..
# 94965  fffcf5a5ff07b0908bd4e2dbc735a684      454          1   1570.00  3  1
# 94966  fffea47cd6d3cc0a88bd621562a9d061      269          1     64.89  2  1
# 94967  ffff371b4d645b6ecea244b27531430a      576          1     89.90  3  1
# 94968  ffff5962728ec6157033ef9805bacc48      127          1    115.00  1  1
# 94969  ffffd2657e2aad2907e67c3e9daecbeb      491          1     56.99  3  1
#
#        M  RFM             segment
# 0      3  113    Active customers
# 1      1  111       Top customers
# 2      2  312   Customers at risk
# 3      1  311   Customers at risk
# 4      3  213  Unsteady customers
# ...   ..  ...                 ...
# 94965  3  313   Customers at risk
# 94966  2  212  Emerging customers
# 94967  2  312   Customers at risk
# 94968  2  112       Top customers
# 94969  1  311   Customers at risk
#
# [94970 rows x 9 columns]

# %%
# Distribution of customers

b = rfm.segment.value_counts()
b
# Out:
# Customers at risk           31569
# Top customers               21113
# Emerging customers          20929
# Active customers            10732
# Unsteady customers          10576
# Potential lost customers       51
# Name: segment, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(x=b.index, y=b.values, palette='rocket')

plt.title('Distribution of customers: RFM-analysis \n', fontsize = 17)
plt.show()
